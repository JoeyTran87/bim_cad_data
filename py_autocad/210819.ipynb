# %%
"""Xử lí toàn bộ Block, Leader, Dim : Color by Block"""
import pyautocad
from pyautocad import Autocad, APoint
import pyautocad, utility
from pyautocad import *
from utility import *
import time, os
from pyautocad import Autocad, APoint,aDouble, ACAD
import unidecode
import re

def color_layer(acad,cad_doc,layer_color = None):
    acad.prompt("Process Layers")
    cad_layers = cad_doc.Layers
    cad_layers_names = [layer.Name for layer in cad_layers]
    print(cad_layers_names)
    if layer_color == None:
        layer_color = input('Vui lòng chọn mã màu: ')
    for layer in cad_layers:
        layer.Color = layer_color
    cad_doc.Regen (True)


def cad_selector(cad_doc,set_name,promp="Select objects"):
    """Phương thức chọn đối tượng trong file CAD"""
    print(promp)
    cad_doc.Utility.Prompt(u"%s\n" % promp)
    try:
        cad_doc.SelectionSets.Item(set_name).Delete()
    except Exception as ex:
        pass
    selection = cad_doc.SelectionSets.Add(set_name)
    selection.SelectOnScreen()
    return selection


def load_color_from_file(acad,path_color_file = None):
    color_by_block = None
    color_by_layer = None
    cad_doc_color = None
    if path_color_file == None:
        path_color_file = input('Color Path File: ')
    color_file_name = path_color_file.split("\\")[-1]
    docs = acad.Application.Documents # print(cad_doc.Name)
    doc_names = [d.Name for d in docs]    
    if os.path.isfile(path_color_file) and not color_file_name in doc_names:
        acad.app.Documents.Open(path_color_file)
        docs = acad.Application.Documents # print(cad_doc.Name)
        doc_names = [d.Name for d in docs] 
    acad.app.ZoomAll()
    while True:
        for d in docs:
            if d.Name == color_file_name:
                cad_doc_color = d
                break
        if cad_doc_color != None:
            break
        else:
            print('Current files NOT INCLUDE your file')
    entities = cad_doc_color.ModelSpace
    for i in range(entities.Count):
        item = entities[i]
        if 'AcDbMText' in item.ObjectName:
            print(item.TextString)
            if item.TextString == 'Text Color By Block':
                color_by_block = item.TrueColor
            if item.TextString == 'Text Color By Layer':
                color_by_layer = item.TrueColor
    if color_by_block != None and color_by_layer != None:
        cad_doc_color.Close()
    return color_by_block,color_by_layer


def open_file(acad,path = None):
    while True:
        if path == None:
            path = input('Đường dẫn file CAD: ')
        if os.path.isfile(path):
            print('Đã load Path')
            break
        else:
            print('Path không tồn tại')
    file_name = path.split("\\")[-1]
    print(f"File name: {file_name}")

    docs = acad.app.Documents # print(cad_doc.Name)
    doc_names = [d.Name for d in docs]
    if not file_name in doc_names:    
        acad.app.Documents.Open(path)
        docs = acad.app.Documents # print(cad_doc.Name)
        doc_names = [d.Name for d in docs]
    print(doc_names)
    while True:
        for d in docs:
            if d.Name == file_name:
                cad_doc = d
                print('Current files include your file')
                break
        if cad_doc != None:
            break
        else:
            print('Current files NOT INCLUDE your file')
    acad.app.ZoomAll()
    cad_doc.Regen (True)
    return cad_doc


def change_color_to_by_block(cad_doc,name_set):
    """Đổi màu đối tượng thành By Block"""
    elems = cad_doc.SelectionSets.Item(name_set)
    print([e.ObjectName for e in elems])
    for e in elems:
    #     color.SetRGB(0,103,172)
        e.TrueColor = color_by_block
    cad_doc.Regen (True)


def color_block_childs_by_block(cad_doc,color_by_block):
    cad_doc_blocks = cad_doc.Blocks
    cad_doc_blocks_filterer = []
    for block in cad_doc_blocks:
        if not '*' in block.Name:
            for i in range(block.Count):
                try:
                    block.Item(i).TrueColor = color_by_block
                    if 'Dimension' in block.Item(i).ObjectName:                  
                        dim = block.Item(i)                    
                        print(dim.ObjectName)
                        try:
                            dim.DimensionLineColor = color_by_block.EntityColor
                        except Exception as ex:
                            print(ex)
                        try:
                            dim.ExtensionLineColor = color_by_block.EntityColor
                        except Exception as ex:
                            print(ex)
                        try:
                            dim.TextColor = color_by_block.EntityColor
                        except Exception as ex:
                            print(ex)
                    if 'Leader' in block.Item(i).ObjectName:                  
                        leader = block.Item(i)  
                        print(leader.ObjectName)
                        try:
                            leader.DimensionLineColor = color_by_block.EntityColor
                        except Exception as ex:
                            print(ex)
                except Exception as ex:
                    print(ex)
                    pass
            cad_doc_blocks_filterer.append(cad_doc_blocks_filterer)
    cad_doc.Regen (True)

# %%
def report_items(cad_doc):
    ms = cad_doc.ModelSpace
    dic = {}
    list_item_names = [ms.Item(i).ObjectName for i in range(ms.Count)]
    for item in list_item_names:
        dic[item] = list_item_names.count(item)
    
    print('\n'.join([f"{item} : {dic[item]}" for item in dic]))
    return dic

def get_items(cad_doc,in_text = 'AcDb'):
    ms = cad_doc.ModelSpace
    list_items = [ms.Item(i) for i in range(ms.Count) if in_text in ms.Item(i).ObjectName]
    return list_items
    
def text_VI(texts):
    for t in texts:
        new_value = t.TextString
        new_value = re.sub("-","_",re.sub("%%C","D= ",unidecode.unidecode(new_value).strip()))
        t.TextString = new_value
        
        print(t.TextString)

# %%
cad = None
cad_app = None
cad_doc = None
path = None
color_by_block = None
color_by_layer = None

cad = Autocad(create_if_not_exists=True, visible=True)
cad.app
if cad: print('Autocad Opened')
    
    
print([doc.Name for doc in cad.app.Documents]) 
cad_doc = cad.app.Documents[0]

ms = cad_doc.ModelSpace

dic_items = report_items(cad_doc)

texts = get_items(cad_doc,in_text = 'Text')

text_VI(texts)
# Out:
# Autocad Opened
# ['BIM-DOORS.dwg']
# AcDbBlockReference : 95
# AcDbHatch : 53
# AcDbPolyline : 376
# AcDbRotatedDimension : 129
# AcDbLine : 155
# AcDbArc : 4
# AcDbLeader : 21
# AcDbText : 368
# AcDbWipeout : 4
# AcDbCircle : 5
# MOTOR
# 42
# 9
# 6
# 7
# 5
# KY HIEU _
# 3
# 4
# 2
# 1
# MAT BANG _ PLAN
# MAT DUNG _ ELEVATION
# KINH _ GLASS
# 10
# 11
# GHI CHU _ NOTE
# 8
# KEM TRANG _ WHITE CREAM COLOR
# KHUNG THEP _ STEEL FRAME
# THEP SON TINH DIEN _ POWDER COATED STEEL
# CUA CUON CONG NGHIEP _ SECTIONAL DOOR WAS REQUIRED
# SYMBOL
# KHUNG NGOAI
# VAT LIEU
# MAU _ COLOR
# SO LUONG
# KHUNG CANH
# EXTERNAL FRAME
# FRAMES
# MATERIAL
# QUANTILY
# TEN CUA
# DOOR NAME
# KICH THUOC
# SIZE
# MO TA
# DESCRIPTION
# MOTOR
# 02
# KEM TRANG _ WHITE CREAM COLOR
# KHUNG THEP _ STEEL FRAME
# THEP SON TINH DIEN _ POWDER COATED STEEL
# CUA NHOM KINH _ ALUMINUM GLASS DOORS
# CUA CUON THEP , CO MOTOR DIEN _  ROLLING DOOR
# CUA DI 2 CANH _ DOOR 2 WINGS
# 8mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 8 LY
# _WHITE CREAM COLOR
# KEM TRANG
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# 9
# 6
# 7
# 5
# KY HIEU _
# 3
# 4
# 2
# 1
# MAT BANG _ PLAN
# MAT DUNG _ ELEVATION
# KINH _ GLASS
# 10
# 11
# GHI CHU _ NOTE
# 8
# SYMBOL
# KHUNG NGOAI
# VAT LIEU
# MAU _ COLOR
# SO LUONG
# KHUNG CANH
# EXTERNAL FRAME
# FRAMES
# MATERIAL
# QUANTILY
# TEN CUA
# DOOR NAME
# KICH THUOC
# SIZE
# MO TA
# DESCRIPTION
# CUA NHOM KINH
# CUA DI 1 CANH _ DOOR 1 WINGS
# 6mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 6 LY
# _WHITE CREAM COLOR
# KEM TRANG
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# _8mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 8 LY
# KEM TRANG
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# ALU & GLASS WINDOW
# CUA SO KHUNG NHOM KINH
# _ AWNING WINDOW
# CUA SO BAT
# _ ALUMINUM GLASS DOORS
# 9
# 6
# 7
# 5
# KY HIEU _
# 3
# 4
# 2
# 1
# MAT BANG _ PLAN
# MAT DUNG _ ELEVATION
# KINH _ GLASS
# 10
# 11
# GHI CHU _ NOTE
# 8
# SYMBOL
# KHUNG NGOAI
# VAT LIEU
# MAU _ COLOR
# SO LUONG
# KHUNG CANH
# EXTERNAL FRAME
# FRAMES
# MATERIAL
# QUANTILY
# TEN CUA
# DOOR NAME
# KICH THUOC
# SIZE
# MO TA
# DESCRIPTION
# _ LOUVER
# LAM NHOM THONG GIO
# _WHITE CREAM COLOR
# KEM TRANG
# 50
# 06
# KEM TRANG _ WHITE CREAM COLOR
# KHUNG THEP _ STEEL FRAME
# THEP SON TINH DIEN _ POWDER COATED STEEL
# 9
# 6
# 7
# 5
# KY HIEU _
# 3
# 4
# 2
# 1
# MAT BANG _ PLAN
# MAT DUNG _ ELEVATION
# KINH _ GLASS
# 10
# 11
# GHI CHU _ NOTE
# 8
# SYMBOL
# KHUNG NGOAI
# VAT LIEU
# MAU _ COLOR
# SO LUONG
# KHUNG CANH
# EXTERNAL FRAME
# FRAMES
# MATERIAL
# QUANTILY
# TEN CUA
# DOOR NAME
# KICH THUOC
# SIZE
# MO TA
# DESCRIPTION
# MOTOR
# 02
# KEM TRANG _ WHITE CREAM COLOR
# KHUNG THEP _ STEEL FRAME
# THEP SON TINH DIEN _ POWDER COATED STEEL
# CUA DI 1 CANH _ DOOR 1 WINGS
# _6mm THK. DIM GLASS
# KINH MO DAY 6 LY
# _WHITE CREAM COLOR
# KEM TRANG
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# _6mm THK. DIM GLASS
# KINH MO DAY 6 LY
# _WHITE CREAM COLOR
# KEM TRANG
# 10
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# CUA DI 1 CANH _ DOOR 1 WINGS
# _WITH FORM PANEL DOOR
# THEO MAU CUA PANEL
# _ GREY
# XAM
# 10
# _WITH FORM PANEL DOOR
# THEO MAU CUA PANEL
# CUA NHOM KINH
# ALUMINUM GLASS DOORS
# CUA NHOM KINH
# ALUMINUM GLASS DOORS
# STEEL FRAME DOOR
# CUA DI PANEL PU KHUNG THEP
# ALU & GLASS WINDOW
# CUA SO KHUNG NHOM KINH
# _SLIDING WINDOW
# CUA SO TRUOT 4 CANH
# _8mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 8 LY
# 16
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# _6mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 6 LY
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# _6mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 6 LY
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# _6mm THK. TEMPERED GLASS
# KINH CUONG LUC DAY 6 LY
# 02
# NHOM SON TINH DIEN
# _ALUMINIUM FRAME
# KHUNG NHOM
# ALU ELECTROSTATIC PAINTING
# ALU & GLASS WINDOW
# CUA SO KHUNG NHOM KINH
# _ AWNING WINDOW
# CUA SO BAT
# ALU & GLASS WINDOW
# CUA SO KHUNG NHOM KINH
# _ SLIDING DOOR
# CUA SO LUA 2 CANH
# ALU & GLASS WINDOW
# CUA SO KHUNG NHOM KINH
# _ AWNING WINDOW
# CUA SO BAT
# _WHITE CREAM COLOR
# KEM TRANG
# _WHITE CREAM COLOR
# KEM TRANG
# _WHITE CREAM COLOR
# KEM TRANG
# _WHITE CREAM COLOR
# KEM TRANG
# CUA THOAT HIEM
# _ EMERGENCY EXIT
# AUTOMATIC DOORS CLOSERS
# CUA TU DONG CO CU CHO HOI
# LUOI SOI THUY TINH
# CHONG CON TRUNG
# FIBER GLASS INSERT NET
# LUOI INOX CHONG CON TRUNG
# GRID INOX 304 B20
# CUA CUON CONG NGHIEP _ SECTIONAL DOOR WAS REQUIRED
# CUA CUON CONG NGHIEP _ SECTIONAL DOOR WAS REQUIRED
# _WITH FORM PANEL DOOR
# THEO MAU CUA PANEL
# _ GREY
# XAM
# 02
# _WITH FORM PANEL DOOR
# THEO MAU CUA PANEL
# _FIREPROOF DOORS EI 60
# CUA CHONG CHAY EI 60
# AUTOMATIC DOORS CLOSERS
# CUA TU DONG CO CU CHO HOI
# STEEL FRAME DOOR
# CUA DI PANEL PU KHUNG THEP
# CUA THOAT HIEM
# _ EMERGENCY EXIT
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# _FIRE_FIGHTING GLASSES
# KINH CUONG LUC CHONG CHAY
# _THEP SON TINH DIEN
# _ STEEL , POWDER COATED
# _THEP
# _STEEL
# _THEP
# _STEEL
# _WHITE CREAM COLOR
# _FIRE_FIGHTING GLASSES
# KINH CUONG LUC CHONG CHAY
# _WITH FORM PANEL DOOR
# THEO MAU CUA PANEL
# _ GREY
# XAM
# 01
# _WITH FORM PANEL DOOR
# THEO MAU CUA PANEL
# STEEL FRAME DOOR
# CUA DI PANEL PU KHUNG THEP
# CUA THOAT HIEM
# _ EMERGENCY EXIT
# AUTOMATIC DOORS CLOSERS
# CUA TU DONG CO CU CHO HOI
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# MOTOR
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# _FIREPROOF DOORS EI 60
# CUA CHONG CHAY EI 60
# THEP C
# CHONG CHAY EI60
# THEP C
# CHONG CHAY EI60
# 07
# KEM TRANG _ WHITE CREAM COLOR
# KHUNG THEP _ STEEL FRAME
# THEP SON TINH DIEN _ POWDER COATED STEEL
# CUA CUON THEP , CO MOTOR DIEN _  ROLLING DOOR
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# TRU BAO VE CHONG VA D= 150x5mm
# D= 150x5mm COLUMN PROTECTION
# CUA CUON CHONG CHAY EI60
# ROLLING DOOR , FIRE PROTECTED EI60
# _ALUMINIUM FRAME
# KHUNG NHOM
# _ALUMINIUM FRAME
# KHUNG NHOM
# _ALUMINIUM FRAME
# KHUNG NHOM
# _ALUMINIUM FRAME
# KHUNG NHOM
# _ALUMINIUM FRAME
# KHUNG NHOM
# _ALUMINIUM FRAME
# KHUNG NHOM
